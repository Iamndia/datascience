# %%
#@title Twitter Auth Token

twitter_auth_token = '30dde069dbade2838a76108cc8fd040a9dfaccaa' # change this auth token

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,958 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,944 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,540 kB]
# Get:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [77.3 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,387 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,245 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,729 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,552 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,255 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Fetched 31.9 MB in 5s (6,687 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.20).
# gnupg is already the newest version (2.2.27-3ubuntu2.3).
# gnupg set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 91 not upgraded.
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Get:4 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [11.6 kB]
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 23.7 kB in 2s (15.1 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 91 not upgraded.
# Need to get 32.0 MB of archives.
# After this operation, 199 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.19.2-1nodesource1 [32.0 MB]
# Fetched 32.0 MB in 1s (50.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 126102 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.19.2-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.19.2-1nodesource1) ...
# Setting up nodejs (20.19.2-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# v20.19.2

# %%
# Crawl Data

filename = 'blt.csv'
search_keyword = 'BLT since:2024-12-29 until:2025-05-21 lang:id'
limit = 500

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/blt.csv, renaming to ./tweets-data/blt.old.csv
#
# -- Scrolling... (1) (2)
# Filling in keywords: BLT since:2024-12-29 until:2025-05-21 lang:id
#
#  (3) (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 16
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 34
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 52
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 71
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 83
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 98
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 116
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3) (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 134
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 153
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 172
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 188
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 205
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 219
#
# --Taking a break, waiting for 10 seconds...
#
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 239
#
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 258
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 277
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 297
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 315
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 333
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 348
#
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 365
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 380
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 399
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 412
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 430
#
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 448
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3) (4) (5) (6) (7)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 466
#
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 483
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/blt.csv
# Total tweets saved: 501
# Got 501 tweets, done scrolling...
# ⠙

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1924670639362994607  Tue May 20 03:36:53 +0000 2025               0
# 1    1924668535764353200  Tue May 20 03:28:32 +0000 2025               0
# 2    1924667585951629805  Tue May 20 03:24:45 +0000 2025               2
# 3    1924666591016583677  Tue May 20 03:20:48 +0000 2025               0
# 4    1924653806106902663  Tue May 20 02:30:00 +0000 2025               0
# ..                   ...                             ...             ...
# 496  1919618782105915865  Tue May 06 12:17:21 +0000 2025               0
# 497  1919618782105915865  Tue May 06 12:09:43 +0000 2025               0
# 498  1919562550922117470  Tue May 06 12:09:14 +0000 2025               0
# 499  1919618782105915865  Tue May 06 12:03:45 +0000 2025               0
# 500  1919722051478421852  Tue May 06 11:58:36 +0000 2025               0
#
#                                              full_text               id_str  \
# 0    Bertempat di Aula Desa Gumulan Jln.Pringgodani...  1924670639362994607
# 1    Cek PORTO BLT - Sepatu Wanita Model Balerina S...  1924668535764353200
# 2    Cek BLT BBM Rp600.000 Hari Ini Selasa 20 Mei 2...  1924667585951629805
# 3    BLT aman Lansia nyaman. Polsek Padang Bolak tu...  1924666591016583677
# 4    Apakah Nama Kamu Termasuk Penerima Bansos BLT ...  1924653806106902663
# ..                                                 ...                  ...
# 496  @CNNIndonesia gak logis &amp; full ngarang sal...  1919728186272653810
# 497  @CNNIndonesia Knpa lah klean yg mimpin negeri ...  1919726265789034999
# 498  @mikel392905 @kemgelapan Ben e koyo tong sampa...  1919726143722111246
# 499  @CNNIndonesia Info dong cara biar dapet BLT se...  1919724767265091654
# 500         @Rouliberation @rihanna pengen blt keknya   1919723470092697907
#
#                                            image_url in_reply_to_screen_name  \
# 0    https://pbs.twimg.com/media/GrXNvhrbEAATiYN.jpg                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3    https://pbs.twimg.com/media/GrXKDU1bkAA1zQu.jpg                     NaN
# 4                                                NaN                     NaN
# ..                                               ...                     ...
# 496                                              NaN            CNNIndonesia
# 497                                              NaN            CNNIndonesia
# 498                                              NaN             mikel392905
# 499                                              NaN            CNNIndonesia
# 500                                              NaN           Rouliberation
#
#     lang  location  quote_count  reply_count  retweet_count  \
# 0     in       NaN            0            0              0
# 1     in       NaN            0            0              0
# 2     in       NaN            0            0              0
# 3     in       NaN            0            0              0
# 4     in       NaN            0            0              0
# ..   ...       ...          ...          ...            ...
# 496   in       NaN            0            0              0
# 497   in       NaN            0            0              0
# 498   in       NaN            0            1              0
# 499   in       NaN            0            0              0
# 500   in       NaN            0            1              0
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/01Koramil/status/192467063936299...   962971574969102336
# 1    https://x.com/saymaa09/status/1924668535764353200  1166656551702032385
# 2    https://x.com/romisaputra_3/status/19246675859...  1767373840110469120
# 3    https://x.com/HumasS43484/status/1924666591016...  1838661874575101952
# 4    https://x.com/disway_update/status/19246538061...  1912027937676853249
# ..                                                 ...                  ...
# 496  https://x.com/Maharanisaa_/status/191972818627...  1253650985458655233
# 497  https://x.com/rbarbanso/status/191972626578903...  1755013028897226752
# 498  https://x.com/condro_n43/status/19197261437221...           2169304824
# 499  https://x.com/kuetarot/status/1919724767265091654           2786673653
# 500  https://x.com/Issa_scenteu/status/191972347009...  1698870711849459712
#
#           username
# 0        01Koramil
# 1         saymaa09
# 2    romisaputra_3
# 3      HumasS43484
# 4    disway_update
# ..             ...
# 496   Maharanisaa_
# 497      rbarbanso
# 498     condro_n43
# 499       kuetarot
# 500   Issa_scenteu
#
# [501 rows x 15 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 501.
