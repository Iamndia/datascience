# %%
import requests
from bs4 import BeautifulSoup
import time
import csv
from urllib.parse import urljoin
import random
import traceback
import re

# --- FUNGSI BARU UNTUK MENGAMBIL KONTEN ARTIKEL (DIPERBAIKI SESUAI INFO ANDA) ---
def get_article_content(article_url, headers):
    """
    Mengunjungi URL artikel dan mengambil teks dari <div class="media_desc">.
    Jika tidak ditemukan, akan mencoba fallback ke metode pencarian paragraf umum.
    """
    print(f"    Mengambil konten dari: {article_url}")
    article_text = ""
    try:
        # Jeda kecil SEBELUM request ke halaman artikel individu
        time.sleep(random.uniform(0.5, 1.5)) # Mengurangi sedikit jeda untuk testing

        article_response = requests.get(article_url, headers=headers, timeout=12) # Timeout sedikit diperpanjang
        article_response.raise_for_status()
        detail_article_soup = BeautifulSoup(article_response.content, 'html.parser')

        # PRIORITAS: Cari <div class="media_desc"> seperti yang Anda sebutkan
        media_desc_div = detail_article_soup.find('div', class_='media_desc')

        if media_desc_div:
            # Ambil semua teks dari dalam div ini.
            # get_text(separator='\n', strip=True) akan menggabungkan teks dari semua elemen anak,
            # memisahkan blok teks yang berbeda dengan baris baru, dan menghapus spasi ekstra.
            article_text = media_desc_div.get_text(separator='\n', strip=True)
            if article_text:
                print(f"      Konten ditemukan dalam 'div.media_desc'. Panjang: {len(article_text)} chars.")
            else:
                print(f"      'div.media_desc' ditemukan, tetapi tidak ada teks di dalamnya di {article_url}.")
        else:
            # FALLBACK jika 'div.media_desc' tidak ditemukan.
            # Anda bisa menghapus bagian fallback ini jika yakin 'media_desc' selalu ada
            # dan berisi konten yang diinginkan.
            print(f"      Peringatan: 'div.media_desc' TIDAK ditemukan di {article_url}. Mencoba fallback (area konten umum + <p>).")

            # Coba cari area konten yang lebih umum seperti sebelumnya
            # (Anda mungkin perlu menyesuaikan class_recompile ini berdasarkan inspeksi lebih lanjut jika fallback ini sering terpakai)
            content_area = detail_article_soup.find('div', class_=re.compile(r'detail__body-text|article__body|entry-content|post-content|read__content', re.IGNORECASE))

            if content_area:
                paragraphs = content_area.find_all('p', recursive=False) # Ambil <p> yang merupakan anak langsung dari content_area
                if not paragraphs: # Jika tidak ada <p> anak langsung, coba cari semua <p> di dalamnya
                    paragraphs = content_area.find_all('p')

                collected_texts = []
                for p_index, p in enumerate(paragraphs):
                    # Logika filter paragraf (bisa disesuaikan atau dihapus jika tidak perlu)
                    parent_classes_to_skip = ['lihat-juga', 'related-articles', 'baca-juga', 'artikel-terkait', 'recommendation-box', 'bottom-of-article']
                    skip_paragraph = False
                    # Cek apakah paragraf atau parentnya memiliki class yang ingin di-skip
                    current_element = p
                    while current_element and current_element != content_area and current_element != detail_article_soup.body:
                        if current_element.has_attr('class') and any(cls in current_element['class'] for cls in parent_classes_to_skip):
                            skip_paragraph = True
                            # print(f"        Skipping paragraph {p_index+1} due to parent class: {current_element['class']}")
                            break
                        current_element = current_element.parent

                    if 'script' in str(p).lower() or 'style' in str(p).lower(): # Hindari script/style di dalam p
                        skip_paragraph = True
                        # print(f"        Skipping paragraph {p_index+1} due to script/style content")

                    if not skip_paragraph:
                        text_content = p.get_text(strip=True)
                        if text_content: # Hanya tambahkan jika ada teks
                            collected_texts.append(text_content)

                article_text = "\n".join(collected_texts)
                if article_text:
                     print(f"      Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: {len(article_text)} chars.")

            if not article_text: # Jika fallback juga tidak menghasilkan apa-apa
                 print(f"      Peringatan: Tidak ada teks konten yang terambil dari {article_url} dengan metode fallback saat ini.")

    except requests.exceptions.RequestException as e:
        print(f"    Error saat mengambil konten artikel {article_url}: {e}")
    except Exception as e_detail:
        print(f"    Error saat parsing konten artikel {article_url}: {e_detail}")
        # traceback.print_exc() # Uncomment untuk debug error parsing yang lebih detail

    return article_text
# --- AKHIR FUNGSI ---

# URL awal / halaman pertama (dari contoh Anda)
current_page_url = 'https://www.detik.com/search/searchall?query=blt&page=1&result_type=relevansi'

# Untuk menyimpan semua data yang di-scrape
semua_data_scraped = []

# Opsional: Batas maksimal data yang ingin diambil
MAKSIMAL_DATA_TOTAL = 100 # DIKECILKAN LAGI untuk testing cepat pengambilan konten
jumlah_data_terscrape_total = 0

# Opsional: Batas maksimal halaman yang ingin di-scrape
MAKSIMAL_HALAMAN = None # Batasi hanya beberapa halaman untuk testing konten
jumlah_halaman_terscrape = 0

# Header, termasuk User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

print("Memulai proses scraping...")

while current_page_url and \
      (MAKSIMAL_HALAMAN is None or jumlah_halaman_terscrape < MAKSIMAL_HALAMAN) and \
      (MAKSIMAL_DATA_TOTAL is None or jumlah_data_terscrape_total < MAKSIMAL_DATA_TOTAL):

    print(f"Mengambil data dari halaman pencarian: {current_page_url}")
    jumlah_halaman_terscrape += 1

    try:
        response = requests.get(current_page_url, headers=headers, timeout=15)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        items_di_halaman_ini = soup.find_all('article') # Asumsi selector ini sudah baik untuk Anda

        if not items_di_halaman_ini and jumlah_halaman_terscrape > 1:
            print("Tidak ada item berita ditemukan di halaman pencarian ini, mungkin halaman terakhir atau selector item salah.")
            break
        elif not items_di_halaman_ini and jumlah_halaman_terscrape == 1:
            print("Tidak ada item berita ditemukan di halaman pencarian PERTAMA. Periksa selector item ('article') Anda!")
            break

        print(f"Ditemukan {len(items_di_halaman_ini)} item berita di halaman pencarian ini.")

        for item_index, item in enumerate(items_di_halaman_ini):
            if MAKSIMAL_DATA_TOTAL is not None and jumlah_data_terscrape_total >= MAKSIMAL_DATA_TOTAL:
                print(f"Batas maksimal {MAKSIMAL_DATA_TOTAL} data (artikel) telah tercapai.")
                current_page_url = None # Set None untuk menghentikan loop while luar
                break # Keluar dari loop for item

            try:
                title_element = item.find('h3', class_='media__title')
                judul_berita = title_element.get_text(strip=True) if title_element else "Judul tidak ditemukan"

                link_element = item.find('a')
                link_berita = link_element['href'] if link_element and link_element.has_attr('href') else "Link tidak ditemukan"

                if link_berita != "Link tidak ditemukan" and not link_berita.startswith('http'):
                    link_berita = urljoin(response.url, link_berita)

                konten_artikel = ""
                if link_berita != "Link tidak ditemukan":
                    # Memanggil fungsi untuk mengambil konten artikel
                    konten_artikel = get_article_content(link_berita, headers)
                else:
                    print(f"  Skipping pengambilan konten untuk item ke-{item_index+1} karena link tidak ditemukan.")


                data_item = {
                    'judul': judul_berita,
                    'link': link_berita,
                    'konten': konten_artikel,
                    'halaman_sumber_pencarian': current_page_url
                }
                semua_data_scraped.append(data_item)
                jumlah_data_terscrape_total += 1
                print(f"  -> Data artikel ke-{jumlah_data_terscrape_total} BERHASIL diproses: {judul_berita} (Panjang Konten: {len(konten_artikel)} chars)")

            except Exception as e_item:
                print(f"  Error saat memproses satu item berita ke-{item_index+1}: {e_item}")
                traceback.print_exc()

        if current_page_url is None: # Jika sudah di-set None oleh inner loop (batas data tercapai)
            break # Keluar dari loop while

        # --- BAGIAN UNTUK MENEMUKAN HALAMAN PENCARIAN BERIKUTNYA ---
        next_button = None
        # (Logika pencarian next_button Anda yang sudah bekerja sebelumnya bisa diletakkan di sini)
        # Contoh sederhana (pastikan ini bekerja atau gunakan logika multi-upaya Anda sebelumnya):
        if not next_button:
            next_button = soup.find('a', rel='next')
            if next_button: print("Tombol 'Next' (pencarian) ditemukan via rel='next'")
        if not next_button:
            possible_buttons = soup.find_all('a', class_=re.compile(r'pagination|page-link|next', re.IGNORECASE))
            if not possible_buttons: possible_buttons = soup.find_all('a')
            for button in possible_buttons:
                button_text = button.get_text(strip=True).lower()
                if button_text == "berikutnya" or button_text == "next" or button_text == "selanjutnya" or button_text == "»":
                    next_button = button
                    print(f"Tombol 'Next' (pencarian) ditemukan via teks persis: '{button_text}'")
                    break
            if not next_button: # Coba yang mengandung teks
                 for button in possible_buttons:
                    button_text = button.get_text(strip=True).lower()
                    if "berikutnya" in button_text or "next" in button_text or "selanjutnya" in button_text:
                        next_button = button
                        print(f"Tombol 'Next' (pencarian) ditemukan via teks mengandung: '{button_text}'")
                        break
        if not next_button:
            next_button = soup.select_one('a[title*="Berikutnya"], a[title*="Next"], a[aria-label*="Berikutnya"], a[aria-label*="Next"]')
            if next_button: print("Tombol 'Next' (pencarian) ditemukan via atribut title atau aria-label")

        if next_button and next_button.has_attr('href'):
            next_page_link = next_button['href']
            current_page_url = urljoin(response.url, next_page_link)
            print(f"Link halaman pencarian berikutnya ditemukan: {current_page_url}")
        else:
            print("Tombol 'Next' (halaman pencarian berikutnya) TIDAK ditemukan. Mengakhiri pagination.")
            current_page_url = None
        # --- AKHIR BAGIAN MENEMUKAN HALAMAN PENCARIAN BERIKUTNYA ---

        if current_page_url:
            jeda_halaman_pencarian = random.uniform(2, 5) # Jeda antar halaman pencarian
            print(f"Menunggu {jeda_halaman_pencarian:.2f} detik sebelum ke halaman pencarian berikutnya...")
            time.sleep(jeda_halaman_pencarian)

    except requests.exceptions.HTTPError as e:
        print(f"Error HTTP saat mengakses halaman pencarian {current_page_url if isinstance(current_page_url, str) else 'URL tidak valid'}: {e}")
        if hasattr(e, 'response') and e.response is not None and e.response.status_code == 404:
            print("Halaman pencarian tidak ditemukan (404).")
        break
    except requests.exceptions.RequestException as e:
        print(f"Error koneksi saat mengakses halaman pencarian {current_page_url if isinstance(current_page_url, str) else 'URL tidak valid'}: {e}")
        break
    except Exception as e:
        print(f"Terjadi kesalahan umum pada loop utama: {e}")
        traceback.print_exc()
        break

print(f"\nProses scraping selesai.")
print(f"Total data artikel yang berhasil di-scrape: {len(semua_data_scraped)} item (dari {jumlah_halaman_terscrape} halaman pencarian).")

if semua_data_scraped:
    nama_file_csv = 'data_detik_blt_dengan_konten_v2.csv'
    if semua_data_scraped:
        fieldnames = semua_data_scraped[0].keys()
        try:
            with open(nama_file_csv, mode='w', newline='', encoding='utf-8') as file_csv:
                writer = csv.DictWriter(file_csv, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerows(semua_data_scraped)
            print(f"Data telah disimpan ke {nama_file_csv}")
        except IOError:
            print(f"Error: Tidak bisa menulis ke file {nama_file_csv}")
        except Exception as e:
            print(f"Error saat menyimpan ke CSV: {e}")
else:
    print("Tidak ada data untuk disimpan.")
# Out:
# Memulai proses scraping...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=1&result_type=relevansi
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://news.detik.com/berita/d-7924631/wamendes-80-ribu-kopdes-merah-putih-launching-juli-bisa-salurkan-blt-bansos
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/berita/d-7924631/wamendes-80-ribu-kopdes-merah-putih-launching-juli-bisa-salurkan-blt-bansos. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3187 chars.
#   -> Data artikel ke-1 BERHASIL diproses: Wamendes: 80 Ribu Kopdes Merah Putih Launching Juli, Bisa Salurkan BLT-Bansos (Panjang Konten: 3187 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7622373/subsidi-bbm-listrik-diganti-ke-blt-tergantung-keputusan-prabowo
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7622373/subsidi-bbm-listrik-diganti-ke-blt-tergantung-keputusan-prabowo. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2917 chars.
#   -> Data artikel ke-2 BERHASIL diproses: Subsidi BBM & Listrik Diganti ke BLT Tergantung Keputusan Prabowo (Panjang Konten: 2917 chars)
#     Mengambil konten dari: https://www.detik.com/jatim/berita/d-7890412/kepedulian-walkot-vinanda-ke-warga-kediri-bagikan-blt-kursi-roda
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jatim/berita/d-7890412/kepedulian-walkot-vinanda-ke-warga-kediri-bagikan-blt-kursi-roda. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2019 chars.
#   -> Data artikel ke-3 BERHASIL diproses: Kepedulian Walkot Vinanda ke Warga Kediri, Bagikan BLT-Kursi Roda (Panjang Konten: 2019 chars)
#     Mengambil konten dari: https://20.detik.com/detikupdate/20241103-241103083/video-subsidi-bbm-listrik-tak-tepat-sasaran-bahlil-bakal-kaji-jadi-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikupdate/20241103-241103083/video-subsidi-bbm-listrik-tak-tepat-sasaran-bahlil-bakal-kaji-jadi-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 200 chars.
#   -> Data artikel ke-4 BERHASIL diproses: Video: Subsidi BBM-Listrik Tak Tepat Sasaran, Bahlil Bakal Kaji Jadi BLT (Panjang Konten: 200 chars)
#     Mengambil konten dari: https://www.detik.com/sumut/berita/d-7618281/kata-bahlil-soal-opsi-alihkan-subsisi-bbm-listrik-untuk-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sumut/berita/d-7618281/kata-bahlil-soal-opsi-alihkan-subsisi-bbm-listrik-untuk-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1612 chars.
#   -> Data artikel ke-5 BERHASIL diproses: Kata Bahlil Soal Opsi Alihkan Subsisi BBM-Listrik untuk BLT (Panjang Konten: 1612 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7532828/dpr-hingga-petani-tolak-wacana-subsidi-pupuk-diganti-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7532828/dpr-hingga-petani-tolak-wacana-subsidi-pupuk-diganti-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3697 chars.
#   -> Data artikel ke-6 BERHASIL diproses: DPR hingga Petani Tolak Wacana Subsidi Pupuk Diganti BLT (Panjang Konten: 3697 chars)
#     Mengambil konten dari: https://news.detik.com/berita/d-7625385/pemerintah-kaji-subsidi-bbm-diubah-jadi-blt-mensos-lagi-konsolidasi-data
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/berita/d-7625385/pemerintah-kaji-subsidi-bbm-diubah-jadi-blt-mensos-lagi-konsolidasi-data. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1601 chars.
#   -> Data artikel ke-7 BERHASIL diproses: Pemerintah Kaji Subsidi BBM Diubah Jadi BLT, Mensos: Lagi Konsolidasi Data (Panjang Konten: 1601 chars)
#     Mengambil konten dari: https://finance.detik.com/foto-bisnis/d-7845116/ratusan-buruh-rokok-di-pekalongan-terima-blt-cukai
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/foto-bisnis/d-7845116/ratusan-buruh-rokok-di-pekalongan-terima-blt-cukai. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 169 chars.
#   -> Data artikel ke-8 BERHASIL diproses: Ratusan Buruh Rokok di Pekalongan Terima BLT Cukai (Panjang Konten: 169 chars)
#     Mengambil konten dari: https://oto.detik.com/berita/d-7641493/ktp-dipinjam-buat-akali-pajak-progresif-kendaraan-bisa-bisa-tak-dapat-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://oto.detik.com/berita/d-7641493/ktp-dipinjam-buat-akali-pajak-progresif-kendaraan-bisa-bisa-tak-dapat-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1998 chars.
#   -> Data artikel ke-9 BERHASIL diproses: KTP Dipinjam Buat Akali Pajak Progresif Kendaraan, Bisa-bisa Tak Dapat BLT! (Panjang Konten: 1998 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7668527/zulhas-sebut-blt-rp-600-ribu-bisa-disalahgunakan-buat-judi-online
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7668527/zulhas-sebut-blt-rp-600-ribu-bisa-disalahgunakan-buat-judi-online. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1541 chars.
#   -> Data artikel ke-10 BERHASIL diproses: Zulhas Sebut BLT Rp 600 Ribu Bisa Disalahgunakan buat Judi Online (Panjang Konten: 1541 chars)
#     Mengambil konten dari: https://finance.detik.com/industri/d-7846558/hampir-500-pekerja-dapat-blt-dana-bagi-hasil-cukai-tembakau
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/industri/d-7846558/hampir-500-pekerja-dapat-blt-dana-bagi-hasil-cukai-tembakau. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3201 chars.
#   -> Data artikel ke-11 BERHASIL diproses: Hampir 500 Pekerja Dapat BLT Dana Bagi Hasil Cukai Tembakau (Panjang Konten: 3201 chars)
#     Mengambil konten dari: https://news.detik.com/pilkada/d-7638442/dharma-pongrekun-ajak-warga-jangan-terbiasa-blt-kita-dididik-jadi-pengemis
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/pilkada/d-7638442/dharma-pongrekun-ajak-warga-jangan-terbiasa-blt-kita-dididik-jadi-pengemis. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2116 chars.
#   -> Data artikel ke-12 BERHASIL diproses: Dharma Pongrekun Ajak Warga Jangan Terbiasa BLT: Kita Dididik Jadi Pengemis (Panjang Konten: 2116 chars)
# Tombol 'Next' (pencarian) ditemukan via teks persis: 'next'
# Link halaman pencarian berikutnya ditemukan: https://www.detik.com/search/searchall?query=blt&page=2
# Menunggu 2.03 detik sebelum ke halaman pencarian berikutnya...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=2
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7422875/singapura-bakal-cairkan-blt-rp-10-juta-ke-1-5-juta-warganya
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7422875/singapura-bakal-cairkan-blt-rp-10-juta-ke-1-5-juta-warganya. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3234 chars.
#   -> Data artikel ke-13 BERHASIL diproses: Singapura Bakal Cairkan BLT Rp 10 Juta ke 1,5 Juta Warganya! (Panjang Konten: 3234 chars)
#     Mengambil konten dari: https://www.detik.com/jatim/berita/d-7755664/simak-skema-pencairan-jadwal-dan-syarat-menerima-blt-bbm-2025
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jatim/berita/d-7755664/simak-skema-pencairan-jadwal-dan-syarat-menerima-blt-bbm-2025. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1795 chars.
#   -> Data artikel ke-14 BERHASIL diproses: Simak Skema Pencairan, Jadwal dan Syarat Menerima BLT BBM 2025 (Panjang Konten: 1795 chars)
#     Mengambil konten dari: https://www.detik.com/jabar/hukum-dan-kriminal/d-7755502/eks-kades-di-purwakarta-jadi-tersangka-korupsi-blt-dana-desa
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jabar/hukum-dan-kriminal/d-7755502/eks-kades-di-purwakarta-jadi-tersangka-korupsi-blt-dana-desa. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2165 chars.
#   -> Data artikel ke-15 BERHASIL diproses: Eks Kades di Purwakarta Jadi Tersangka Korupsi BLT Dana Desa (Panjang Konten: 2165 chars)
#     Mengambil konten dari: https://20.detik.com/detikupdate/20241030-241030172/video-hasan-janji-tingkatkan-blt-untuk-atasi-kemiskinan-surya-itu-normatif
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikupdate/20241030-241030172/video-hasan-janji-tingkatkan-blt-untuk-atasi-kemiskinan-surya-itu-normatif. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 144 chars.
#   -> Data artikel ke-16 BERHASIL diproses: Video Hasan Janji Tingkatkan BLT untuk Atasi Kemiskinan, Surya: Itu Normatif (Panjang Konten: 144 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7637326/bocoran-3-skema-pengalihan-subsidi-menjadi-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7637326/bocoran-3-skema-pengalihan-subsidi-menjadi-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1826 chars.
#   -> Data artikel ke-17 BERHASIL diproses: Bocoran 3 Skema Pengalihan Subsidi Menjadi BLT (Panjang Konten: 1826 chars)
#     Mengambil konten dari: https://www.detik.com/sumbagsel/hukum-dan-kriminal/d-7724451/mantan-kades-di-muratara-jadi-tersangka-kasus-korupsi-dana-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sumbagsel/hukum-dan-kriminal/d-7724451/mantan-kades-di-muratara-jadi-tersangka-kasus-korupsi-dana-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2362 chars.
#   -> Data artikel ke-18 BERHASIL diproses: Mantan Kades di Muratara Jadi Tersangka Kasus Korupsi Dana BLT (Panjang Konten: 2362 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7721670/bahlil-pastikan-ada-blt-buat-pengganti-subsidi-bbm-dan-listrik
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7721670/bahlil-pastikan-ada-blt-buat-pengganti-subsidi-bbm-dan-listrik. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2478 chars.
#   -> Data artikel ke-19 BERHASIL diproses: Bahlil Pastikan Ada BLT buat Pengganti Subsidi BBM dan Listrik (Panjang Konten: 2478 chars)
#     Mengambil konten dari: https://finance.detik.com/foto-bisnis/d-7535678/4-657-buruh-rokok-di-kediri-dapat-blt-rp-1-juta
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/foto-bisnis/d-7535678/4-657-buruh-rokok-di-kediri-dapat-blt-rp-1-juta. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 143 chars.
#   -> Data artikel ke-20 BERHASIL diproses: 4.657 Buruh Rokok di Kediri Dapat BLT Rp 1 Juta (Panjang Konten: 143 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7313379/blt-mitigasi-risiko-pangan-tak-kunjung-cair-ini-dalih-airlangga
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7313379/blt-mitigasi-risiko-pangan-tak-kunjung-cair-ini-dalih-airlangga. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1224 chars.
#   -> Data artikel ke-21 BERHASIL diproses: BLT Mitigasi Risiko Pangan Tak Kunjung Cair, Ini Dalih Airlangga (Panjang Konten: 1224 chars)
#     Mengambil konten dari: https://finance.detik.com/industri/d-7870745/241-pekerja-dapat-blt-dana-bagi-hasil-tembakau-rp-800-ribu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/industri/d-7870745/241-pekerja-dapat-blt-dana-bagi-hasil-tembakau-rp-800-ribu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2667 chars.
#   -> Data artikel ke-22 BERHASIL diproses: 241 Pekerja Dapat BLT Dana Bagi Hasil Tembakau Rp 800 Ribu (Panjang Konten: 2667 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7682249/kemenkeu-beberkan-rencana-penyaluran-subsidi-bbm-jadi-blt-di-2025
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7682249/kemenkeu-beberkan-rencana-penyaluran-subsidi-bbm-jadi-blt-di-2025. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1975 chars.
#   -> Data artikel ke-23 BERHASIL diproses: Kemenkeu Beberkan Rencana Penyaluran Subsidi BBM Jadi BLT di 2025 (Panjang Konten: 1975 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7658924/bahlil-mau-bertemu-sri-mulyani-bahas-subsidi-bbm-bentuk-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7658924/bahlil-mau-bertemu-sri-mulyani-bahas-subsidi-bbm-bentuk-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2265 chars.
#   -> Data artikel ke-24 BERHASIL diproses: Bahlil Mau Bertemu Sri Mulyani, Bahas Subsidi BBM Bentuk BLT (Panjang Konten: 2265 chars)
# Tombol 'Next' (pencarian) ditemukan via teks persis: 'next'
# Link halaman pencarian berikutnya ditemukan: https://www.detik.com/search/searchall?query=blt&page=3
# Menunggu 4.17 detik sebelum ke halaman pencarian berikutnya...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=3
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://finance.detik.com/energi/d-7658865/bahlil-bocorkan-skema-subsidi-bbm-nggak-semua-buat-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7658865/bahlil-bocorkan-skema-subsidi-bbm-nggak-semua-buat-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2053 chars.
#   -> Data artikel ke-25 BERHASIL diproses: Bahlil Bocorkan Skema Subsidi BBM, Nggak Semua buat BLT (Panjang Konten: 2053 chars)
#     Mengambil konten dari: https://www.detik.com/sulsel/berita/d-7820917/cara-cek-penerima-blt-bbm-2025-serta-syarat-besaran-hingga-skemanya
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sulsel/berita/d-7820917/cara-cek-penerima-blt-bbm-2025-serta-syarat-besaran-hingga-skemanya. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2701 chars.
#   -> Data artikel ke-26 BERHASIL diproses: Cara Cek Penerima BLT BBM 2025, serta Syarat, Besaran, hingga Skemanya (Panjang Konten: 2701 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7305129/blt-mitigasi-risiko-pangan-tak-kunjung-cair-airlangga-bilang-begini
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7305129/blt-mitigasi-risiko-pangan-tak-kunjung-cair-airlangga-bilang-begini. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1262 chars.
#   -> Data artikel ke-27 BERHASIL diproses: BLT Mitigasi Risiko Pangan Tak Kunjung Cair, Airlangga Bilang Begini (Panjang Konten: 1262 chars)
#     Mengambil konten dari: https://20.detik.com/detikupdate/20240202-240202084/penjelasan-jokowi-soal-tebar-blt-jelang-pemilu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikupdate/20240202-240202084/penjelasan-jokowi-soal-tebar-blt-jelang-pemilu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 272 chars.
#   -> Data artikel ke-28 BERHASIL diproses: Penjelasan Jokowi soal Tebar BLT Jelang Pemilu (Panjang Konten: 272 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7651478/bahlil-buka-bukaan-skema-subsidi-bbm-jadi-blt-hampir-final
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7651478/bahlil-buka-bukaan-skema-subsidi-bbm-jadi-blt-hampir-final. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2624 chars.
#   -> Data artikel ke-29 BERHASIL diproses: Bahlil Buka-bukaan Skema Subsidi BBM Jadi BLT Hampir Final (Panjang Konten: 2624 chars)
#     Mengambil konten dari: https://www.detik.com/jatim/berita/d-7427821/segini-besaran-blt-dana-cukai-tembakau-yang-diterima-buruh-rokok-surabaya
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jatim/berita/d-7427821/segini-besaran-blt-dana-cukai-tembakau-yang-diterima-buruh-rokok-surabaya. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1846 chars.
#   -> Data artikel ke-30 BERHASIL diproses: Segini Besaran BLT Dana Cukai Tembakau yang Diterima Buruh Rokok Surabaya (Panjang Konten: 1846 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7636915/ini-tiga-bocoran-pengalihan-subsidi-bbm-ke-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7636915/ini-tiga-bocoran-pengalihan-subsidi-bbm-ke-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1929 chars.
#   -> Data artikel ke-31 BERHASIL diproses: Ini Tiga Bocoran Pengalihan Subsidi BBM ke BLT (Panjang Konten: 1929 chars)
#     Mengambil konten dari: https://finance.detik.com/foto-bisnis/d-7445389/senyum-semringah-buruh-pabrik-rokok-terima-blt-rp-1-4-juta-dana-hasil-cukai
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/foto-bisnis/d-7445389/senyum-semringah-buruh-pabrik-rokok-terima-blt-rp-1-4-juta-dana-hasil-cukai. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 169 chars.
#   -> Data artikel ke-32 BERHASIL diproses: Senyum Semringah Buruh Pabrik Rokok Terima BLT Rp 1,4 Juta Dana Hasil Cukai (Panjang Konten: 169 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7617999/bahlil-blak-blakan-opsi-subsidi-jadi-blt-buat-bbm-listrik
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7617999/bahlil-blak-blakan-opsi-subsidi-jadi-blt-buat-bbm-listrik. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1692 chars.
#   -> Data artikel ke-33 BERHASIL diproses: Bahlil Blak-blakan Opsi Subsidi Jadi BLT buat BBM-Listrik (Panjang Konten: 1692 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7617265/skema-baru-subsidi-energi-lagi-digodok-diubah-jadi-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7617265/skema-baru-subsidi-energi-lagi-digodok-diubah-jadi-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2398 chars.
#   -> Data artikel ke-34 BERHASIL diproses: Skema Baru Subsidi Energi Lagi Digodok, Diubah Jadi BLT? (Panjang Konten: 2398 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7755132/heboh-kabar-blt-rp-5-juta-buat-umkm-kementerian-pastikan-hoaks
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7755132/heboh-kabar-blt-rp-5-juta-buat-umkm-kementerian-pastikan-hoaks. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1486 chars.
#   -> Data artikel ke-35 BERHASIL diproses: Heboh Kabar BLT Rp 5 Juta buat UMKM, Kementerian Pastikan Hoaks (Panjang Konten: 1486 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7231947/airlangga-pastikan-blt-rp-600-ribu-cair-sebelum-lebaran
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7231947/airlangga-pastikan-blt-rp-600-ribu-cair-sebelum-lebaran. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1505 chars.
#   -> Data artikel ke-36 BERHASIL diproses: Airlangga Pastikan BLT Rp 600 Ribu Cair Sebelum Lebaran (Panjang Konten: 1505 chars)
# Tombol 'Next' (pencarian) ditemukan via teks persis: 'next'
# Link halaman pencarian berikutnya ditemukan: https://www.detik.com/search/searchall?query=blt&page=4
# Menunggu 3.41 detik sebelum ke halaman pencarian berikutnya...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=4
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7262738/kemensos-pastikan-pesan-berantai-tambahan-blt-rp-400-ribu-hoaks
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7262738/kemensos-pastikan-pesan-berantai-tambahan-blt-rp-400-ribu-hoaks. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1986 chars.
#   -> Data artikel ke-37 BERHASIL diproses: Kemensos Pastikan Pesan Berantai Tambahan BLT Rp 400 Ribu Hoaks! (Panjang Konten: 1986 chars)
#     Mengambil konten dari: https://20.detik.com/detikupdate/20240202-240202084/penjelasan-jokowi-soal-tebar-blt-jelang-pemilu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikupdate/20240202-240202084/penjelasan-jokowi-soal-tebar-blt-jelang-pemilu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 272 chars.
#   -> Data artikel ke-38 BERHASIL diproses: Penjelasan Jokowi soal Tebar BLT Jelang Pemilu (Panjang Konten: 272 chars)
#     Mengambil konten dari: https://www.detik.com/sumbagsel/bisnis/d-7232554/kapan-blt-mitigasi-pangan-cair-ini-jawaban-menko-perekonomian
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sumbagsel/bisnis/d-7232554/kapan-blt-mitigasi-pangan-cair-ini-jawaban-menko-perekonomian. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1130 chars.
#   -> Data artikel ke-39 BERHASIL diproses: Kapan BLT Mitigasi Pangan Cair? Ini Jawaban Menko Perekonomian (Panjang Konten: 1130 chars)
#     Mengambil konten dari: https://20.detik.com/detikupdate/20231215-231215048/momen-jokowi-bagikan-blt-el-nino-ke-warga-malang
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikupdate/20231215-231215048/momen-jokowi-bagikan-blt-el-nino-ke-warga-malang. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 160 chars.
#   -> Data artikel ke-40 BERHASIL diproses: Momen Jokowi Bagikan BLT El Nino ke Warga Malang (Panjang Konten: 160 chars)
#     Mengambil konten dari: https://www.detik.com/sumbagsel/hukum-dan-kriminal/d-7677796/kejari-lubuklinggau-akan-tetapkan-2-tersangka-kasus-korupsi-dana-bos-dan-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sumbagsel/hukum-dan-kriminal/d-7677796/kejari-lubuklinggau-akan-tetapkan-2-tersangka-kasus-korupsi-dana-bos-dan-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2186 chars.
#   -> Data artikel ke-41 BERHASIL diproses: Kejari Lubuklinggau Akan Tetapkan 2 Tersangka Kasus Korupsi Dana BOS dan BLT (Panjang Konten: 2186 chars)
#     Mengambil konten dari: https://www.detik.com/bali/berita/d-7734185/masyarakat-tabanan-mulai-sejahtera-penerimaan-bantuan-sosial-menurun
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/bali/berita/d-7734185/masyarakat-tabanan-mulai-sejahtera-penerimaan-bantuan-sosial-menurun. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1639 chars.
#   -> Data artikel ke-42 BERHASIL diproses: Masyarakat Tabanan Mulai Sejahtera, Penerimaan Bantuan Sosial Menurun (Panjang Konten: 1639 chars)
#     Mengambil konten dari: https://www.detik.com/jabar/hukum-dan-kriminal/d-7688872/eks-sekdes-di-sukabumi-dibui-usai-sedot-dana-blt-rp-349-juta
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jabar/hukum-dan-kriminal/d-7688872/eks-sekdes-di-sukabumi-dibui-usai-sedot-dana-blt-rp-349-juta. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3664 chars.
#   -> Data artikel ke-43 BERHASIL diproses: Eks Sekdes di Sukabumi Dibui Usai Sedot Dana BLT Rp 349 Juta (Panjang Konten: 3664 chars)
#     Mengambil konten dari: https://finance.detik.com/foto-bisnis/d-6894017/blt-cair-buruh-rokok-dapat-rp-1-5-juta
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/foto-bisnis/d-6894017/blt-cair-buruh-rokok-dapat-rp-1-5-juta. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 115 chars.
#   -> Data artikel ke-44 BERHASIL diproses: BLT Cair! Buruh Rokok Dapat Rp 1,5 Juta (Panjang Konten: 115 chars)
#     Mengambil konten dari: https://www.detik.com/jatim/berita/d-7484010/kata-petani-madiun-soal-wacana-pupuk-subsidi-diganti-jadi-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jatim/berita/d-7484010/kata-petani-madiun-soal-wacana-pupuk-subsidi-diganti-jadi-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2795 chars.
#   -> Data artikel ke-45 BERHASIL diproses: Kata Petani Madiun Soal Wacana Pupuk Subsidi Diganti Jadi BLT (Panjang Konten: 2795 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7205950/beredar-link-pendaftaran-blt-rp-400-ribu-kemensos-pastikan-hoax
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7205950/beredar-link-pendaftaran-blt-rp-400-ribu-kemensos-pastikan-hoax. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1689 chars.
#   -> Data artikel ke-46 BERHASIL diproses: Beredar Link Pendaftaran BLT Rp 400 Ribu, Kemensos Pastikan Hoax! (Panjang Konten: 1689 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7203171/penyaluran-blt-rp-600-ribu-mundur-jadi-bulan-puasa
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7203171/penyaluran-blt-rp-600-ribu-mundur-jadi-bulan-puasa. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2308 chars.
#   -> Data artikel ke-47 BERHASIL diproses: Penyaluran BLT Rp 600 Ribu Mundur, Jadi Bulan Puasa (Panjang Konten: 2308 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7659429/luhut-ungkap-bansos-dampak-ppn-12-bukan-blt-biar-nggak-buat-judi
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7659429/luhut-ungkap-bansos-dampak-ppn-12-bukan-blt-biar-nggak-buat-judi. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2819 chars.
#   -> Data artikel ke-48 BERHASIL diproses: Luhut Ungkap Bansos Dampak PPN 12% Bukan BLT, Biar Nggak buat Judi (Panjang Konten: 2819 chars)
# Tombol 'Next' (pencarian) ditemukan via teks persis: 'next'
# Link halaman pencarian berikutnya ditemukan: https://www.detik.com/search/searchall?query=blt&page=5
# Menunggu 3.89 detik sebelum ke halaman pencarian berikutnya...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=5
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://www.detik.com/sumut/hukum-dan-kriminal/d-7634641/selewengkan-dana-blt-untuk-judol-kepala-kantor-pos-di-natuna-ditangkap
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sumut/hukum-dan-kriminal/d-7634641/selewengkan-dana-blt-untuk-judol-kepala-kantor-pos-di-natuna-ditangkap. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2355 chars.
#   -> Data artikel ke-49 BERHASIL diproses: Selewengkan Dana BLT untuk Judol, Kepala Kantor Pos di Natuna Ditangkap (Panjang Konten: 2355 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7212524/hadapi-kenaikan-harga-pangan-blt-rp-600-ribu-cair-bulan-depan
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7212524/hadapi-kenaikan-harga-pangan-blt-rp-600-ribu-cair-bulan-depan. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2415 chars.
#   -> Data artikel ke-50 BERHASIL diproses: Hadapi Kenaikan Harga Pangan, BLT Rp 600 Ribu Cair Bulan Depan (Panjang Konten: 2415 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7196649/blt-rp-600-ribu-belum-juga-cair-airlangga-ungkap-penyebabnya
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7196649/blt-rp-600-ribu-belum-juga-cair-airlangga-ungkap-penyebabnya. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1460 chars.
#   -> Data artikel ke-51 BERHASIL diproses: BLT Rp 600 Ribu Belum Juga Cair, Airlangga Ungkap Penyebabnya (Panjang Konten: 1460 chars)
#     Mengambil konten dari: https://20.detik.com/detikupdate/20230103-230103086/sandiaga-uno-khawatir-jika-blt-umkm-dihentikan
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikupdate/20230103-230103086/sandiaga-uno-khawatir-jika-blt-umkm-dihentikan. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 117 chars.
#   -> Data artikel ke-52 BERHASIL diproses: Sandiaga Uno Khawatir Jika BLT UMKM Dihentikan (Panjang Konten: 117 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7621580/bahlil-bocorkan-skema-baru-subsidi-listrik-dan-bbm-makin-dekat-jadi-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7621580/bahlil-bocorkan-skema-baru-subsidi-listrik-dan-bbm-makin-dekat-jadi-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1797 chars.
#   -> Data artikel ke-53 BERHASIL diproses: Bahlil Bocorkan Skema Baru Subsidi Listrik dan BBM, Makin Dekat Jadi BLT (Panjang Konten: 1797 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7166646/jokowi-tebar-blt-mulai-februari-langsung-dibayar-rp-600-ribu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7166646/jokowi-tebar-blt-mulai-februari-langsung-dibayar-rp-600-ribu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2209 chars.
#   -> Data artikel ke-54 BERHASIL diproses: Jokowi Tebar BLT Mulai Februari, Langsung Dibayar Rp 600 Ribu! (Panjang Konten: 2209 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7621477/bahlil-pastikan-subsidi-lpg-tak-diganti-blt-tapi-harus-daftar-nik
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7621477/bahlil-pastikan-subsidi-lpg-tak-diganti-blt-tapi-harus-daftar-nik. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1678 chars.
#   -> Data artikel ke-55 BERHASIL diproses: Bahlil Pastikan Subsidi LPG Tak Diganti BLT, tapi Harus Daftar NIK (Panjang Konten: 1678 chars)
#     Mengambil konten dari: https://finance.detik.com/foto-bisnis/d-6833323/jokowi-kunjungi-pasar-tradisional-di-bengkulu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/foto-bisnis/d-6833323/jokowi-kunjungi-pasar-tradisional-di-bengkulu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 151 chars.
#   -> Data artikel ke-56 BERHASIL diproses: Jokowi Kunjungi Pasar Tradisional di Bengkulu (Panjang Konten: 151 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7618177/subsidi-bbm-listrik-mau-diubah-jadi-blt-tahun-ini-bahlil-doain-aja
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7618177/subsidi-bbm-listrik-mau-diubah-jadi-blt-tahun-ini-bahlil-doain-aja. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1332 chars.
#   -> Data artikel ke-57 BERHASIL diproses: Subsidi BBM & Listrik Mau Diubah Jadi BLT Tahun Ini? Bahlil: Doain Aja (Panjang Konten: 1332 chars)
#     Mengambil konten dari: https://www.detik.com/sumut/berita/d-7173893/jokowi-jelaskan-alasan-bagi-bagi-blt-jelang-pemilu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sumut/berita/d-7173893/jokowi-jelaskan-alasan-bagi-bagi-blt-jelang-pemilu. Mencoba fallback (area konten umum + <p>).
#       Peringatan: Tidak ada teks konten yang terambil dari https://www.detik.com/sumut/berita/d-7173893/jokowi-jelaskan-alasan-bagi-bagi-blt-jelang-pemilu dengan metode fallback saat ini.
#   -> Data artikel ke-58 BERHASIL diproses: Jokowi Jelaskan Alasan Bagi-bagi BLT Jelang Pemilu (Panjang Konten: 0 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7172928/bagi-bagi-blt-jelang-pemilu-jokowi-sudah-melalui-persetujuan-dpr
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7172928/bagi-bagi-blt-jelang-pemilu-jokowi-sudah-melalui-persetujuan-dpr. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2625 chars.
#   -> Data artikel ke-59 BERHASIL diproses: Bagi-bagi BLT Jelang Pemilu, Jokowi: Sudah Melalui Persetujuan DPR (Panjang Konten: 2625 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7166412/jokowi-bagi-bagi-blt-rp-200-ribu-mulai-februari
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7166412/jokowi-bagi-bagi-blt-rp-200-ribu-mulai-februari. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1501 chars.
#   -> Data artikel ke-60 BERHASIL diproses: Jokowi Bagi-bagi BLT Rp 200 Ribu Mulai Februari! (Panjang Konten: 1501 chars)
# Tombol 'Next' (pencarian) ditemukan via teks persis: 'next'
# Link halaman pencarian berikutnya ditemukan: https://www.detik.com/search/searchall?query=blt&page=6
# Menunggu 4.86 detik sebelum ke halaman pencarian berikutnya...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=6
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://www.detik.com/jatim/berita/d-7421842/ribuan-buruh-rokok-di-surabaya-terima-blt-dana-cukai-tembakau
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jatim/berita/d-7421842/ribuan-buruh-rokok-di-surabaya-terima-blt-dana-cukai-tembakau. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1857 chars.
#   -> Data artikel ke-61 BERHASIL diproses: Ribuan Buruh Rokok di Surabaya Terima BLT Dana Cukai Tembakau (Panjang Konten: 1857 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7219916/4-bansos-yang-cair-bulan-puasa-ini-ada-blt-rp-600-ribu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7219916/4-bansos-yang-cair-bulan-puasa-ini-ada-blt-rp-600-ribu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 5644 chars.
#   -> Data artikel ke-62 BERHASIL diproses: 4 Bansos yang Cair Bulan Puasa Ini, Ada BLT Rp 600 Ribu (Panjang Konten: 5644 chars)
#     Mengambil konten dari: https://20.detik.com/detikupdate/20241103-241103083/video-subsidi-bbm-listrik-tak-tepat-sasaran-bahlil-bakal-kaji-jadi-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikupdate/20241103-241103083/video-subsidi-bbm-listrik-tak-tepat-sasaran-bahlil-bakal-kaji-jadi-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 200 chars.
#   -> Data artikel ke-63 BERHASIL diproses: Video: Subsidi BBM-Listrik Tak Tepat Sasaran, Bahlil Bakal Kaji Jadi BLT (Panjang Konten: 200 chars)
#     Mengambil konten dari: https://20.detik.com/detikflash/20220916-220916094/ahy-blt-produk-sby-dulu-ditentang-tapi-sekarang-ditiru
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikflash/20220916-220916094/ahy-blt-produk-sby-dulu-ditentang-tapi-sekarang-ditiru. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 188 chars.
#   -> Data artikel ke-64 BERHASIL diproses: AHY: BLT Produk SBY Dulu Ditentang Tapi Sekarang Ditiru (Panjang Konten: 188 chars)
#     Mengambil konten dari: https://news.detik.com/berita/d-7158932/airlangga-salurkan-beras-blt-ke-warga-indramayu-sesuai-amanat-presiden
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/berita/d-7158932/airlangga-salurkan-beras-blt-ke-warga-indramayu-sesuai-amanat-presiden. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2407 chars.
#   -> Data artikel ke-65 BERHASIL diproses: Airlangga Salurkan Beras-BLT ke Warga Indramayu: Sesuai Amanat Presiden (Panjang Konten: 2407 chars)
#     Mengambil konten dari: https://www.detik.com/bali/nusra/d-7565570/kunker-ke-alor-jokowi-akan-bagi-blt-dan-kunjungi-smk-1-kalabahi
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/bali/nusra/d-7565570/kunker-ke-alor-jokowi-akan-bagi-blt-dan-kunjungi-smk-1-kalabahi. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1324 chars.
#   -> Data artikel ke-66 BERHASIL diproses: Kunker ke Alor, Jokowi Akan Bagi BLT dan Kunjungi SMK 1 Kalabahi (Panjang Konten: 1324 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7167084/3-fakta-blt-rp-600-ribu-yang-dibagi-jokowi-mulai-februari
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7167084/3-fakta-blt-rp-600-ribu-yang-dibagi-jokowi-mulai-februari. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2458 chars.
#   -> Data artikel ke-67 BERHASIL diproses: 3 Fakta BLT Rp 600 Ribu yang Dibagi Jokowi Mulai Februari (Panjang Konten: 2458 chars)
#     Mengambil konten dari: https://finance.detik.com/foto-bisnis/d-6822131/subsidi-bbm-dihapus-presiden-nigeria-bakal-beri-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/foto-bisnis/d-6822131/subsidi-bbm-dihapus-presiden-nigeria-bakal-beri-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 168 chars.
#   -> Data artikel ke-68 BERHASIL diproses: Subsidi BBM Dihapus, Presiden Nigeria Bakal Beri 'BLT' (Panjang Konten: 168 chars)
#     Mengambil konten dari: https://news.detik.com/pemilu/d-7157015/ganjar-tanya-warga-kendal-blt-sudah-tepat-sasaran-belum
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/pemilu/d-7157015/ganjar-tanya-warga-kendal-blt-sudah-tepat-sasaran-belum. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2300 chars.
#   -> Data artikel ke-69 BERHASIL diproses: Ganjar Tanya Warga Kendal: BLT Sudah Tepat Sasaran Belum? (Panjang Konten: 2300 chars)
#     Mengambil konten dari: https://news.detik.com/berita/d-7110575/jokowi-bagikan-blt-el-nino-di-banyuwangi-warga-bersorak-gembira
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/berita/d-7110575/jokowi-bagikan-blt-el-nino-di-banyuwangi-warga-bersorak-gembira. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1384 chars.
#   -> Data artikel ke-70 BERHASIL diproses: Jokowi Bagikan BLT El Nino di Banyuwangi, Warga Bersorak Gembira (Panjang Konten: 1384 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7178383/jokowi-tebar-blt-rp-600-ribu-subsidi-pupuk-jelang-pilpres-duitnya-dari-mana
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7178383/jokowi-tebar-blt-rp-600-ribu-subsidi-pupuk-jelang-pilpres-duitnya-dari-mana. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3436 chars.
#   -> Data artikel ke-71 BERHASIL diproses: Jokowi Tebar BLT Rp 600 Ribu-Subsidi Pupuk Jelang Pilpres, Duitnya dari Mana? (Panjang Konten: 3436 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7175074/erick-thohir-respons-bagi-bagi-bansos-blt-dikritik-apa-yang-salah
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7175074/erick-thohir-respons-bagi-bagi-bansos-blt-dikritik-apa-yang-salah. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1802 chars.
#   -> Data artikel ke-72 BERHASIL diproses: Erick Thohir Respons Bagi-bagi Bansos-BLT Dikritik: Apa yang Salah? (Panjang Konten: 1802 chars)
# Tombol 'Next' (pencarian) ditemukan via teks persis: 'next'
# Link halaman pencarian berikutnya ditemukan: https://www.detik.com/search/searchall?query=blt&page=7
# Menunggu 4.94 detik sebelum ke halaman pencarian berikutnya...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=7
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7168084/blt-rp-600-ribu-dibagi-bagi-jelang-pemilu-ini-respons-sri-mulyani
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7168084/blt-rp-600-ribu-dibagi-bagi-jelang-pemilu-ini-respons-sri-mulyani. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2260 chars.
#   -> Data artikel ke-73 BERHASIL diproses: BLT Rp 600 Ribu Dibagi-bagi Jelang Pemilu, Ini Respons Sri Mulyani (Panjang Konten: 2260 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7166632/mulai-februari-jokowi-tebar-blt-rp-200-ribu-dari-mana-sumber-duitnya
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7166632/mulai-februari-jokowi-tebar-blt-rp-200-ribu-dari-mana-sumber-duitnya. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2010 chars.
#   -> Data artikel ke-74 BERHASIL diproses: Mulai Februari Jokowi Tebar BLT Rp 200 Ribu, dari Mana Sumber Duitnya? (Panjang Konten: 2010 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7168891/penjelasan-lengkap-sri-mulyani-soal-blt-rp-600-ribu-dibagi-jelang-pemilu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7168891/penjelasan-lengkap-sri-mulyani-soal-blt-rp-600-ribu-dibagi-jelang-pemilu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3689 chars.
#   -> Data artikel ke-75 BERHASIL diproses: Penjelasan Lengkap Sri Mulyani soal BLT Rp 600 Ribu Dibagi Jelang Pemilu (Panjang Konten: 3689 chars)
#     Mengambil konten dari: https://20.detik.com/detikflash/20220916-220916077/blt-bbm-sudah-tersalurkan-ke-12-7-juta-penerima
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikflash/20220916-220916077/blt-bbm-sudah-tersalurkan-ke-12-7-juta-penerima. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 197 chars.
#   -> Data artikel ke-76 BERHASIL diproses: BLT BBM Sudah Tersalurkan ke 12,7 Juta Penerima! (Panjang Konten: 197 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7725395/luhut-bakal-atur-penerima-bansos-tak-bisa-belanja-sembarangan
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7725395/luhut-bakal-atur-penerima-bansos-tak-bisa-belanja-sembarangan. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1552 chars.
#   -> Data artikel ke-77 BERHASIL diproses: Luhut Bakal Atur Penerima Bansos Tak Bisa Belanja Sembarangan (Panjang Konten: 1552 chars)
#     Mengambil konten dari: https://www.detik.com/jateng/jawa-tengah-meriah/d-7463418/haru-petani-tembakau-demak-terima-blt-bagi-hasil-cukai-dari-bupati-eistianah
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jateng/jawa-tengah-meriah/d-7463418/haru-petani-tembakau-demak-terima-blt-bagi-hasil-cukai-dari-bupati-eistianah. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2269 chars.
#   -> Data artikel ke-78 BERHASIL diproses: Haru Petani Tembakau Demak Terima BLT Bagi Hasil Cukai dari Bupati Eisti'anah (Panjang Konten: 2269 chars)
#     Mengambil konten dari: https://finance.detik.com/energi/d-7621757/bahlil-pastikan-kendaraan-pelat-kuning-tetap-dapat-subsidi-bbm
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7621757/bahlil-pastikan-kendaraan-pelat-kuning-tetap-dapat-subsidi-bbm. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1274 chars.
#   -> Data artikel ke-79 BERHASIL diproses: Bahlil Pastikan Kendaraan Pelat Kuning Tetap Dapat Subsidi BBM (Panjang Konten: 1274 chars)
#     Mengambil konten dari: https://finance.detik.com/foto-bisnis/d-6784331/potret-jokowi-bagi-bagi-blt-dan-sembako-di-pasar-tohaga-parung
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/foto-bisnis/d-6784331/potret-jokowi-bagi-bagi-blt-dan-sembako-di-pasar-tohaga-parung. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 165 chars.
#   -> Data artikel ke-80 BERHASIL diproses: Potret Jokowi Bagi-bagi BLT dan Sembako di Pasar Tohaga Parung (Panjang Konten: 165 chars)
#     Mengambil konten dari: https://www.detik.com/jateng/berita/d-7146819/kampanye-di-sukoharjo-ahy-ungkit-program-blt-kur-era-sby
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jateng/berita/d-7146819/kampanye-di-sukoharjo-ahy-ungkit-program-blt-kur-era-sby. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1614 chars.
#   -> Data artikel ke-81 BERHASIL diproses: Kampanye di Sukoharjo, AHY Ungkit Program BLT-KUR Era SBY (Panjang Konten: 1614 chars)
#     Mengambil konten dari: https://news.detik.com/berita/d-7147948/laksanakan-arahan-jokowi-airlangga-salurkan-bansos-dan-blt-di-kalbar
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/berita/d-7147948/laksanakan-arahan-jokowi-airlangga-salurkan-bansos-dan-blt-di-kalbar. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2589 chars.
#   -> Data artikel ke-82 BERHASIL diproses: Laksanakan Arahan Jokowi, Airlangga Salurkan Bansos dan BLT di Kalbar (Panjang Konten: 2589 chars)
#     Mengambil konten dari: https://news.detik.com/berita/d-7141237/airlangga-salurkan-bantuan-pangan-beras-blt-rp-400-ribu-ke-warga-lombok
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/berita/d-7141237/airlangga-salurkan-bantuan-pangan-beras-blt-rp-400-ribu-ke-warga-lombok. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2288 chars.
#   -> Data artikel ke-83 BERHASIL diproses: Airlangga Salurkan Bantuan Pangan Beras-BLT Rp 400 Ribu ke Warga Lombok (Panjang Konten: 2288 chars)
#     Mengambil konten dari: https://www.detik.com/sulsel/berita/d-7103983/bantuan-blt-el-nino-jadwal-link-dan-cara-cek-penerimanya
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sulsel/berita/d-7103983/bantuan-blt-el-nino-jadwal-link-dan-cara-cek-penerimanya. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2584 chars.
#   -> Data artikel ke-84 BERHASIL diproses: Bantuan BLT El Nino: Jadwal, Link, dan Cara Cek Penerimanya (Panjang Konten: 2584 chars)
# Tombol 'Next' (pencarian) ditemukan via teks persis: 'next'
# Link halaman pencarian berikutnya ditemukan: https://www.detik.com/search/searchall?query=blt&page=8
# Menunggu 4.61 detik sebelum ke halaman pencarian berikutnya...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=8
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://finance.detik.com/energi/d-7441108/subsidi-lpg-3-kg-mau-diganti-jadi-blt-penerima-bisa-dapat-rp-120-ribu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/energi/d-7441108/subsidi-lpg-3-kg-mau-diganti-jadi-blt-penerima-bisa-dapat-rp-120-ribu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 5119 chars.
#   -> Data artikel ke-85 BERHASIL diproses: Subsidi LPG 3 Kg Mau Diganti Jadi BLT, Penerima Bisa Dapat Rp 120 Ribu (Panjang Konten: 5119 chars)
#     Mengambil konten dari: https://news.detik.com/pemilu/d-7167854/blt-3-bulan-mulai-dibagikan-awal-februari-cak-imin-ingatkan-presiden
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/pemilu/d-7167854/blt-3-bulan-mulai-dibagikan-awal-februari-cak-imin-ingatkan-presiden. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2126 chars.
#   -> Data artikel ke-86 BERHASIL diproses: BLT 3 Bulan Mulai Dibagikan Awal Februari, Cak Imin Ingatkan Presiden (Panjang Konten: 2126 chars)
#     Mengambil konten dari: https://news.detik.com/pemilu/d-7142318/di-purbalingga-ganjar-bicara-solusi-blt-belum-tepat-sasaran-ktp-sakti
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/pemilu/d-7142318/di-purbalingga-ganjar-bicara-solusi-blt-belum-tepat-sasaran-ktp-sakti. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1663 chars.
#   -> Data artikel ke-87 BERHASIL diproses: Di Purbalingga, Ganjar Bicara Solusi BLT Belum Tepat Sasaran: KTP Sakti (Panjang Konten: 1663 chars)
#     Mengambil konten dari: https://20.detik.com/detikflash/20220916-220916075/mensos-risma-blt-diturunkan-saat-kondisi-tak-stabil
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikflash/20220916-220916075/mensos-risma-blt-diturunkan-saat-kondisi-tak-stabil. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 276 chars.
#   -> Data artikel ke-88 BERHASIL diproses: Mensos Risma: BLT Diturunkan Saat Kondisi Tak Stabil (Panjang Konten: 276 chars)
#     Mengambil konten dari: https://www.detik.com/sulsel/berita/d-7300949/inspektorat-mamuju-usut-kades-tanambuah-diduga-potong-blt-warga
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sulsel/berita/d-7300949/inspektorat-mamuju-usut-kades-tanambuah-diduga-potong-blt-warga. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1914 chars.
#   -> Data artikel ke-89 BERHASIL diproses: Inspektorat Mamuju Usut Kades Tanambuah Diduga Potong BLT Warga (Panjang Konten: 1914 chars)
#     Mengambil konten dari: https://www.detik.com/sulsel/berita/d-7386014/bansos-blt-mitigasi-risiko-pangan-kapan-cair-ini-jadwal-dan-cara-ceknya
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sulsel/berita/d-7386014/bansos-blt-mitigasi-risiko-pangan-kapan-cair-ini-jadwal-dan-cara-ceknya. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2630 chars.
#   -> Data artikel ke-90 BERHASIL diproses: Bansos BLT Mitigasi Risiko Pangan Kapan Cair? Ini Jadwal dan Cara Ceknya (Panjang Konten: 2630 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7281497/terungkap-penyebab-anggaran-kemensos-turun-hingga-blt-el-nino-lenyap
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7281497/terungkap-penyebab-anggaran-kemensos-turun-hingga-blt-el-nino-lenyap. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2901 chars.
#   -> Data artikel ke-91 BERHASIL diproses: Terungkap Penyebab Anggaran Kemensos Turun hingga BLT El Nino 'Lenyap' (Panjang Konten: 2901 chars)
#     Mengambil konten dari: https://finance.detik.com/foto-bisnis/d-6457545/dapat-dari-mana-nih-kok-orang-orang-antre-dikasih-rp-600-ribu
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/foto-bisnis/d-6457545/dapat-dari-mana-nih-kok-orang-orang-antre-dikasih-rp-600-ribu. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 165 chars.
#   -> Data artikel ke-92 BERHASIL diproses: Dapat dari Mana Nih? Kok Orang-orang Antre Dikasih Rp 600 Ribu (Panjang Konten: 165 chars)
#     Mengambil konten dari: https://www.detik.com/sumut/hukum-dan-kriminal/d-7386566/maling-pecahkan-kaca-mobil-bendahara-desa-di-aceh-uang-blt-rp-36-juta-raib
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/sumut/hukum-dan-kriminal/d-7386566/maling-pecahkan-kaca-mobil-bendahara-desa-di-aceh-uang-blt-rp-36-juta-raib. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1395 chars.
#   -> Data artikel ke-93 BERHASIL diproses: Maling Pecahkan Kaca Mobil Bendahara Desa di Aceh, Uang BLT Rp 36 Juta Raib (Panjang Konten: 1395 chars)
#     Mengambil konten dari: https://finance.detik.com/berita-ekonomi-bisnis/d-7114287/airlangga-pastikan-penyaluran-blt-el-nino-rp-7-52-t-tepat-sasaran
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://finance.detik.com/berita-ekonomi-bisnis/d-7114287/airlangga-pastikan-penyaluran-blt-el-nino-rp-7-52-t-tepat-sasaran. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1641 chars.
#   -> Data artikel ke-94 BERHASIL diproses: Airlangga Pastikan Penyaluran BLT El Nino Rp 7,52 T Tepat Sasaran (Panjang Konten: 1641 chars)
#     Mengambil konten dari: https://news.detik.com/pemilu/d-7123816/ganjar-temui-petani-di-blora-terima-keluhan-soal-kur-dan-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/pemilu/d-7123816/ganjar-temui-petani-di-blora-terima-keluhan-soal-kur-dan-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3666 chars.
#   -> Data artikel ke-95 BERHASIL diproses: Ganjar Temui Petani di Blora, Terima Keluhan soal KUR dan BLT (Panjang Konten: 3666 chars)
#     Mengambil konten dari: https://www.detik.com/jateng/bisnis/d-7112913/senangnya-buruh-tani-tembakau-blora-terima-blt-dbhcht-buat-sekolah-anak
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jateng/bisnis/d-7112913/senangnya-buruh-tani-tembakau-blora-terima-blt-dbhcht-buat-sekolah-anak. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 3130 chars.
#   -> Data artikel ke-96 BERHASIL diproses: Senangnya Buruh Tani Tembakau Blora Terima BLT DBHCHT: Buat Sekolah Anak (Panjang Konten: 3130 chars)
# Tombol 'Next' (pencarian) ditemukan via teks persis: 'next'
# Link halaman pencarian berikutnya ditemukan: https://www.detik.com/search/searchall?query=blt&page=9
# Menunggu 3.22 detik sebelum ke halaman pencarian berikutnya...
# Mengambil data dari halaman pencarian: https://www.detik.com/search/searchall?query=blt&page=9
# Ditemukan 12 item berita di halaman pencarian ini.
#     Mengambil konten dari: https://news.detik.com/berita/d-7113573/jokowi-temui-warga-di-manado-pastikan-penyaluran-blt-el-nino-lancar
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://news.detik.com/berita/d-7113573/jokowi-temui-warga-di-manado-pastikan-penyaluran-blt-el-nino-lancar. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 1438 chars.
#   -> Data artikel ke-97 BERHASIL diproses: Jokowi Temui Warga di Manado, Pastikan Penyaluran BLT El Nino Lancar (Panjang Konten: 1438 chars)
#     Mengambil konten dari: https://www.detik.com/jateng/berita/d-7072121/dprd-klaten-minta-penjelasan-buntut-blt-cukai-tembakau-nyasar-ke-kades
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jateng/berita/d-7072121/dprd-klaten-minta-penjelasan-buntut-blt-cukai-tembakau-nyasar-ke-kades. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2824 chars.
#   -> Data artikel ke-98 BERHASIL diproses: DPRD Klaten Minta Penjelasan Buntut BLT Cukai Tembakau Nyasar ke Kades (Panjang Konten: 2824 chars)
#     Mengambil konten dari: https://www.detik.com/jatim/berita/d-7063296/gus-ipul-salurkan-blt-dari-dana-cukai-rokok-jangan-buat-beli-pulsa
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://www.detik.com/jatim/berita/d-7063296/gus-ipul-salurkan-blt-dari-dana-cukai-rokok-jangan-buat-beli-pulsa. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 2228 chars.
#   -> Data artikel ke-99 BERHASIL diproses: Gus Ipul Salurkan BLT dari Dana Cukai Rokok: Jangan Buat Beli Pulsa (Panjang Konten: 2228 chars)
#     Mengambil konten dari: https://20.detik.com/detikflash/20220916-220916050/jokowi-kunker-ke-kepulauan-aru-cek-penyaluran-blt
#       Peringatan: 'div.media_desc' TIDAK ditemukan di https://20.detik.com/detikflash/20220916-220916050/jokowi-kunker-ke-kepulauan-aru-cek-penyaluran-blt. Mencoba fallback (area konten umum + <p>).
#       Konten ditemukan via FALLBACK (area konten umum + <p>). Panjang: 185 chars.
#   -> Data artikel ke-100 BERHASIL diproses: Jokowi Kunker ke Kepulauan Aru, Cek Penyaluran BLT (Panjang Konten: 185 chars)
# Batas maksimal 100 data (artikel) telah tercapai.
#
# Proses scraping selesai.
# Total data artikel yang berhasil di-scrape: 100 item (dari 9 halaman pencarian).
# Data telah disimpan ke data_detik_blt_dengan_konten_v2.csv
